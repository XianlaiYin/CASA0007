# %%
# Out:
# Beijing KPSS Test Statistic: 7.659
# Beijing p-value: 1.000
# Tianjin KPSS Test Statistic: 1.756
# Tianjin p-value: 0.998
# Hebei KPSS Test Statistic: -0.685
# Hebei p-value: 0.851
# Shanxi KPSS Test Statistic: 0.103
# Shanxi p-value: 0.966
# InnerMongolia KPSS Test Statistic: 0.214
# InnerMongolia p-value: 0.973
# Liaoning KPSS Test Statistic: -0.367
# Liaoning p-value: 0.915
# Jilin KPSS Test Statistic: -2.662
# Jilin p-value: 0.081
# Heilongjiang KPSS Test Statistic: -1.691
# Heilongjiang p-value: 0.436
# Shanghai KPSS Test Statistic: 1.423
# Shanghai p-value: 0.997
# Jiangsu KPSS Test Statistic: 1.124
# Jiangsu p-value: 0.995
# Zhejiang KPSS Test Statistic: -1.041
# Zhejiang p-value: 0.738
# Anhui KPSS Test Statistic: 1.646
# Anhui p-value: 0.998
# Fujian KPSS Test Statistic: 0.912
# Fujian p-value: 0.993
# Jiangxi KPSS Test Statistic: 1.320
# Jiangxi p-value: 0.997
# Shandong KPSS Test Statistic: -1.265
# Shandong p-value: 0.645
# Henan KPSS Test Statistic: 0.366
# ...

# %%
# Out:
# Beijing ADF Statistic: 0.704939
# Beijing p-value: 0.013096
# Tianjin ADF Statistic: 0.747763
# Tianjin p-value: 0.010000
# Hebei ADF Statistic: 0.768495
# Hebei p-value: 0.010000
# Shanxi ADF Statistic: 0.769117
# Shanxi p-value: 0.010000
# InnerMongolia ADF Statistic: 0.762019
# InnerMongolia p-value: 0.010000
# Liaoning ADF Statistic: 0.764059
# Liaoning p-value: 0.010000
# Jilin ADF Statistic: 0.730185
# Jilin p-value: 0.010801
# Heilongjiang ADF Statistic: 0.747732
# Heilongjiang p-value: 0.010000
# Shanghai ADF Statistic: 0.430053
# Shanghai p-value: 0.064201
# Jiangsu ADF Statistic: 0.762772
# Jiangsu p-value: 0.010000
# Zhejiang ADF Statistic: 0.768113
# Zhejiang p-value: 0.010000
# Anhui ADF Statistic: 0.768872
# Anhui p-value: 0.010000
# Fujian ADF Statistic: 0.764110
# Fujian p-value: 0.010000
# Jiangxi ADF Statistic: 0.770155
# Jiangxi p-value: 0.010000
# Shandong ADF Statistic: 0.764319
# Shandong p-value: 0.010000
# Henan ADF Statistic: 0.767929
# ...

# %%
# Out:
# C:\Users\xianl\AppData\Roaming\Python\Python39\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\xianl\AppData\Roaming\Python\Python39\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\xianl\AppData\Roaming\Python\Python39\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# C:\Users\xianl\AppData\Roaming\Python\Python39\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# ...
